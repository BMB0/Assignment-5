# %% [markdown]
# # Import Libraries

# %%
# TensorFlow y tf.keras
import tensorflow as tf
from tensorflow import keras
#from sklearn.preprocessing import LabelBinarizer

# Librerias de ayuda
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

print(tf.__version__)
# Out:
# 2.9.1

# %% [markdown]
# # Import Dataset from csv file

# %%
df = pd.read_csv(r'Dataset\dataset-song-genre.csv')
df
# Out:
#                      track_id                       artists  \
# 0      3txHZTpGeVASXa5ARwoRX6                        Frejat
# 1      2e7LBdeiidf0ZC5Qj52u0G                         STU48
# 2      0hlh787aY52rcNvJHnE0Ml             Mike NRG;Weapon X
# 3      3s067jTdOv8wnuUHeXdtjT        NICO Touches the Walls
# 4      4oE62AqzUuiwV09HGxiMlu       Edvard Grieg;Una Bourne
# ...                       ...                           ...
# 91195  0Y1hw2GXV8npQI7C21ZIT1                      Surfaces
# 91196  43QSsuxazI8xms29SYCtxh                 KANA-BOON;もっさ
# 91197  7nbj09isjVmgNYJ7eKBzyt                    Zach Bryan
# 91198  5bVUUTXB0Dg7EzuSZC57ek  Joey Montana;Sebastian Yatra
# 91199  2RjWCcfCOMzKeRJzeoe4h6            Noisia;The Upbeats
#
#                                 album_name  \
# 0            Frejat Ao Vivo No Rock In Rio
# 1                       無謀な夢は覚めることがない【劇場盤】
# 2         Lost in Dreams (Q-Base OST 2008)
# 3                                     オーロラ
# 4      Mozart, Liszt & Others: Piano Works
# ...                                    ...
# 91195                          Hidden Gems
# 91196     ないものねだり - Revenge THE FIRST TAKE
# 91197              Your Perfect Soundtrack
# 91198                 Regageton Para Niños
# 91199                           Dead Limit
#
#                                             track_name  popularity  \
# 0                                Puro Êxtase - Ao Vivo          45
# 1                                         奇跡という名のストーリー          19
# 2                      Lost In Dreams - Weapon X Remix          23
# 3                                                ホログラム          56
# 4      Lyric Pieces I, Op. 12 (Excerpts): No. 6, Norsk           0
# ...                                                ...         ...
# 91195                                      Wave of You           0
# 91196                 ないものねだり - Revenge THE FIRST TAKE          58
# 91197                          Something in the Orange           0
# 91198                                  Suena El Dembow           1
# 91199                                       Dead Limit          44
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 0           292186     False         0.571   0.924    9    -4.727     1
# 1           242099     False         0.368   0.826    6    -3.448     1
# 2           296360     False         0.547   0.867    6    -5.040     1
# 3           248906     False         0.388   0.894    0    -3.425     1
# 4            42306     False         0.345   0.236    2   -21.922     1
# ...            ...       ...           ...     ...  ...       ...   ...
# 91195       213842     False         0.695   0.656    1    -6.038     1
# 91196       256256     False         0.565   0.811    1    -3.745     0
# 91197       228013     False         0.369   0.192    4   -12.151     0
# 91198       195760     False         0.690   0.858    0    -4.431     1
# 91199       361395     False         0.608   0.975    1    -2.008     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.1970      0.179000          0.000004    0.7190   0.5000
# 1           0.0421      0.057200          0.000000    0.2030   0.6630
# 2           0.0326      0.054600          0.489000    0.0735   0.2530
# 3           0.0455      0.000808          0.000000    0.1990   0.7240
# 4           0.0401      0.989000          0.952000    0.2280   0.3800
# ...            ...           ...               ...       ...      ...
# 91195       0.0489      0.057000          0.000000    0.2670   0.3460
# 91196       0.0570      0.014100          0.000000    0.0726   0.6910
# 91197       0.0400      0.555000          0.000008    0.0954   0.1480
# 91198       0.0529      0.189000          0.000000    0.1130   0.7550
# 91199       0.2870      0.004000          0.787000    0.1250   0.0691
#
#          tempo  time_signature    track_genre
# 0      121.056               4          r-n-b
# 1       83.102               4         j-idol
# 2      163.002               4      hardstyle
# 3      156.120               4          anime
# 4      135.677               4      classical
# ...        ...             ...            ...
# 91195   90.986               4           soul
# 91196   87.508               4          j-pop
# 91197  175.212               3        country
# 91198   91.884               4      reggaeton
# 91199  172.106               4  drum-and-bass
#
# [91200 rows x 20 columns]

# %%
df.shape
# Out:
# (91200, 20)

# %% [markdown]
# # Estamos verificando datos con fallas y eliminandolos del dataframe

# %%
df.isna().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %% [markdown]
# # volvemos datos booleanos a numéricos

# %%
df = df.astype({'explicit':'int'})

# %%
df['explicit']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 91195    0
# 91196    0
# 91197    0
# 91198    0
# 91199    0
# Name: explicit, Length: 91199, dtype: int32

# %% [markdown]
# Creamos Diccionario de Labels

# %%
label_dict = dict(enumerate(set(df.track_genre.transpose())))
label_dict
# Out:
# {0: 'french',
#  1: 'children',
#  2: 'german',
#  3: 'hard-rock',
#  4: 'comedy',
#  5: 'mpb',
#  6: 'latino',
#  7: 'guitar',
#  8: 'tango',
#  9: 'progressive-house',
#  10: 'dancehall',
#  11: 'heavy-metal',
#  12: 'funk',
#  13: 'metal',
#  14: 'j-pop',
#  15: 'death-metal',
#  16: 'j-idol',
#  17: 'reggaeton',
#  18: 'forro',
#  19: 'afrobeat',
#  20: 'pagode',
#  21: 'j-dance',
#  22: 'minimal-techno',
#  23: 'psych-rock',
#  24: 'british',
#  25: 'romance',
#  26: 'techno',
#  27: 'swedish',
#  28: 'hardcore',
#  29: 'study',
#  30: 'punk',
#  31: 'chill',
#  32: 'party',
#  33: 'bluegrass',
#  34: 'j-rock',
#  35: 'sleep',
#  36: 'disco',
#  37: 'dubstep',
#  38: 'country',
#  39: 'jazz',
#  40: 'world-music',
#  41: 'idm',
#  42: 'dance',
#  43: 'punk-rock',
#  44: 'spanish',
#  45: 'classical',
#  46: 'cantopop',
#  47: 'black-metal',
#  48: 'mandopop',
#  49: 'power-pop',
#  50: 'salsa',
#  51: 'sertanejo',
#  52: 'reggae',
#  53: 'alternative',
#  54: 'opera',
#  55: 'iranian',
#  56: 'ska',
#  57: 'grunge',
#  58: 'chicago-house',
#  59: 'soul',
#  60: 'folk',
#  61: 'malay',
#  62: 'house',
#  63: 'piano',
#  64: 'groove',
#  65: 'happy',
#  66: 'ambient',
#  67: 'turkish',
#  68: 'sad',
#  69: 'hip-hop',
#  70: 'drum-and-bass',
#  71: 'pop',
#  72: 'honky-tonk',
#  73: 'deep-house',
#  74: 'alt-rock',
#  75: 'latin',
#  76: 'new-age',
#  77: 'emo',
#  78: 'gospel',
#  79: 'industrial',
#  80: 'rockabilly',
#  81: 'samba',
#  82: 'singer-songwriter',
#  83: 'detroit-techno',
#  84: 'acoustic',
#  85: 'trip-hop',
#  86: 'synth-pop',
#  87: 'rock-n-roll',
#  88: 'hardstyle',
#  89: 'indian',
#  90: 'goth',
#  91: 'club',
#  92: 'electronic',
#  93: 'pop-film',
#  94: 'rock',
#  95: 'anime',
#  96: 'r-n-b',
#  97: 'edm',
#  98: 'blues',
#  99: 'trance',
#  100: 'kids',
#  101: 'brazil',
#  102: 'grindcore',
#  103: 'k-pop',
#  104: 'disney',
#  105: 'dub',
#  106: 'indie',
#  107: 'show-tunes',
#  108: 'songwriter',
#  109: 'electro',
#  110: 'garage',
#  111: 'breakbeat',
#  112: 'indie-pop',
#  113: 'metalcore'}

# %% [markdown]
# Creamos Diccionario Invertido

# %%
inv_label_dict = {v: k for k, v in label_dict.items()}
inv_label_dict
# Out:
# {'french': 0,
#  'children': 1,
#  'german': 2,
#  'hard-rock': 3,
#  'comedy': 4,
#  'mpb': 5,
#  'latino': 6,
#  'guitar': 7,
#  'tango': 8,
#  'progressive-house': 9,
#  'dancehall': 10,
#  'heavy-metal': 11,
#  'funk': 12,
#  'metal': 13,
#  'j-pop': 14,
#  'death-metal': 15,
#  'j-idol': 16,
#  'reggaeton': 17,
#  'forro': 18,
#  'afrobeat': 19,
#  'pagode': 20,
#  'j-dance': 21,
#  'minimal-techno': 22,
#  'psych-rock': 23,
#  'british': 24,
#  'romance': 25,
#  'techno': 26,
#  'swedish': 27,
#  'hardcore': 28,
#  'study': 29,
#  'punk': 30,
#  'chill': 31,
#  'party': 32,
#  'bluegrass': 33,
#  'j-rock': 34,
#  'sleep': 35,
#  'disco': 36,
#  'dubstep': 37,
#  'country': 38,
#  'jazz': 39,
#  'world-music': 40,
#  'idm': 41,
#  'dance': 42,
#  'punk-rock': 43,
#  'spanish': 44,
#  'classical': 45,
#  'cantopop': 46,
#  'black-metal': 47,
#  'mandopop': 48,
#  'power-pop': 49,
#  'salsa': 50,
#  'sertanejo': 51,
#  'reggae': 52,
#  'alternative': 53,
#  'opera': 54,
#  'iranian': 55,
#  'ska': 56,
#  'grunge': 57,
#  'chicago-house': 58,
#  'soul': 59,
#  'folk': 60,
#  'malay': 61,
#  'house': 62,
#  'piano': 63,
#  'groove': 64,
#  'happy': 65,
#  'ambient': 66,
#  'turkish': 67,
#  'sad': 68,
#  'hip-hop': 69,
#  'drum-and-bass': 70,
#  'pop': 71,
#  'honky-tonk': 72,
#  'deep-house': 73,
#  'alt-rock': 74,
#  'latin': 75,
#  'new-age': 76,
#  'emo': 77,
#  'gospel': 78,
#  'industrial': 79,
#  'rockabilly': 80,
#  'samba': 81,
#  'singer-songwriter': 82,
#  'detroit-techno': 83,
#  'acoustic': 84,
#  'trip-hop': 85,
#  'synth-pop': 86,
#  'rock-n-roll': 87,
#  'hardstyle': 88,
#  'indian': 89,
#  'goth': 90,
#  'club': 91,
#  'electronic': 92,
#  'pop-film': 93,
#  'rock': 94,
#  'anime': 95,
#  'r-n-b': 96,
#  'edm': 97,
#  'blues': 98,
#  'trance': 99,
#  'kids': 100,
#  'brazil': 101,
#  'grindcore': 102,
#  'k-pop': 103,
#  'disney': 104,
#  'dub': 105,
#  'indie': 106,
#  'show-tunes': 107,
#  'songwriter': 108,
#  'electro': 109,
#  'garage': 110,
#  'breakbeat': 111,
#  'indie-pop': 112,
#  'metalcore': 113}

# %%
train_labels_num = []
for label in df.track_genre.transpose():
    train_labels_num.append(inv_label_dict[label])

train_labels_num
# Out:
# [96,
#  16,
#  88,
#  95,
#  45,
#  18,
#  90,
#  5,
#  18,
#  25,
#  78,
#  44,
#  13,
#  1,
#  87,
#  53,
#  47,
#  43,
#  50,
#  81,
#  42,
#  7,
#  53,
#  20,
#  20,
#  109,
#  108,
#  106,
#  34,
#  37,
#  14,
#  106,
#  93,
#  103,
#  1,
#  51,
#  100,
#  91,
#  71,
#  26,
#  113,
#  34,
#  63,
#  50,
#  24,
#  86,
#  65,
#  15,
#  2,
#  36,
#  42,
#  89,
#  105,
#  13,
#  73,
#  86,
#  72,
#  64,
#  30,
#  84,
#  35,
#  55,
#  55,
#  107,
#  42,
#  60,
#  70,
#  54,
#  30,
#  47,
#  39,
#  7,
#  30,
#  36,
#  34,
#  95,
#  22,
#  40,
#  53,
#  93,
#  60,
#  94,
#  59,
#  93,
#  47,
#  32,
#  33,
#  106,
#  101,
#  5,
#  92,
#  109,
#  11,
#  19,
#  10,
#  95,
#  18,
#  23,
#  17,
#  63,
#  91,
#  78,
#  97,
#  83,
#  42,
#  18,
#  72,
#  19,
#  61,
#  62,
#  57,
#  107,
#  24,
#  18,
#  46,
#  14,
#  58,
#  111,
#  81,
#  41,
#  94,
#  45,
#  112,
#  68,
#  66,
#  101,
#  12,
#  64,
#  4,
#  39,
#  70,
#  45,
#  96,
#  21,
#  9,
#  99,
#  5,
#  0,
#  84,
#  88,
#  82,
#  86,
#  35,
#  62,
#  56,
#  69,
#  81,
#  103,
#  83,
#  17,
#  95,
#  87,
#  34,
#  33,
#  89,
#  79,
#  51,
#  65,
#  113,
#  5,
#  65,
#  65,
#  44,
#  6,
#  6,
#  54,
#  99,
#  24,
#  42,
#  82,
#  110,
#  61,
#  91,
#  73,
#  74,
#  25,
#  62,
#  56,
#  47,
#  103,
#  13,
#  45,
#  36,
#  44,
#  55,
#  41,
#  21,
#  109,
#  73,
#  109,
#  97,
#  85,
#  36,
#  106,
#  87,
#  27,
#  9,
#  98,
#  9,
#  38,
#  69,
#  35,
#  32,
#  59,
#  85,
#  11,
#  94,
#  49,
#  62,
#  51,
#  108,
#  56,
#  113,
#  105,
#  99,
#  91,
#  46,
#  48,
#  102,
#  113,
#  110,
#  96,
#  35,
#  69,
#  84,
#  2,
#  6,
#  77,
#  113,
#  73,
#  39,
#  42,
#  36,
#  20,
#  21,
#  68,
#  2,
#  107,
#  38,
#  81,
#  91,
#  9,
#  57,
#  14,
#  12,
#  21,
#  102,
#  88,
#  38,
#  108,
#  98,
#  30,
#  57,
#  6,
#  83,
#  1,
#  67,
#  26,
#  43,
#  97,
#  14,
#  5,
#  31,
#  100,
#  92,
#  20,
#  81,
#  48,
#  42,
#  88,
#  8,
#  63,
#  5,
#  93,
#  13,
#  63,
#  67,
#  19,
#  45,
#  37,
#  18,
#  45,
#  29,
#  38,
#  45,
#  65,
#  38,
#  66,
#  64,
#  93,
#  18,
#  58,
#  24,
#  18,
#  61,
#  112,
#  25,
#  78,
#  73,
#  10,
#  32,
#  15,
#  41,
#  93,
#  30,
#  111,
#  107,
#  19,
#  92,
#  74,
#  90,
#  45,
#  20,
#  94,
#  50,
#  8,
#  50,
#  72,
#  82,
#  26,
#  63,
#  5,
#  53,
#  55,
#  19,
#  87,
#  108,
#  35,
#  3,
#  102,
#  107,
#  21,
#  44,
#  81,
#  28,
#  75,
#  95,
#  11,
#  52,
#  36,
#  111,
#  95,
#  91,
#  101,
#  51,
#  69,
#  106,
#  44,
#  40,
#  85,
#  71,
#  13,
#  57,
#  59,
#  25,
#  11,
#  24,
#  111,
#  69,
#  8,
#  108,
#  101,
#  4,
#  100,
#  87,
#  5,
#  98,
#  2,
#  0,
#  39,
#  101,
#  66,
#  101,
#  59,
#  69,
#  91,
#  38,
#  81,
#  64,
#  81,
#  104,
#  65,
#  51,
#  98,
#  48,
#  100,
#  102,
#  113,
#  68,
#  52,
#  49,
#  55,
#  7,
#  104,
#  9,
#  15,
#  55,
#  51,
#  42,
#  7,
#  93,
#  96,
#  89,
#  58,
#  108,
#  90,
#  94,
#  102,
#  22,
#  90,
#  25,
#  93,
#  74,
#  50,
#  47,
#  18,
#  60,
#  18,
#  112,
#  1,
#  103,
#  84,
#  4,
#  76,
#  70,
#  86,
#  73,
#  62,
#  35,
#  54,
#  95,
#  11,
#  57,
#  108,
#  106,
#  110,
#  25,
#  88,
#  34,
#  16,
#  99,
#  72,
#  113,
#  29,
#  90,
#  37,
#  25,
#  111,
#  75,
#  44,
#  66,
#  82,
#  36,
#  89,
#  65,
#  41,
#  111,
#  11,
#  54,
#  42,
#  25,
#  3,
#  11,
#  104,
#  42,
#  96,
#  98,
#  49,
#  65,
#  30,
#  111,
#  19,
#  53,
#  11,
#  35,
#  92,
#  15,
#  106,
#  48,
#  88,
#  107,
#  44,
#  76,
#  48,
#  20,
#  55,
#  64,
#  62,
#  64,
#  21,
#  62,
#  17,
#  66,
#  31,
#  107,
#  11,
#  5,
#  55,
#  33,
#  40,
#  50,
#  25,
#  55,
#  87,
#  46,
#  39,
#  75,
#  78,
#  29,
#  30,
#  12,
#  19,
#  68,
#  12,
#  57,
#  55,
#  46,
#  91,
#  81,
#  0,
#  7,
#  97,
#  52,
#  40,
#  5,
#  84,
#  86,
#  20,
#  12,
#  20,
#  76,
#  84,
#  70,
#  29,
#  86,
#  45,
#  112,
#  100,
#  53,
#  98,
#  72,
#  38,
#  59,
#  36,
#  29,
#  87,
#  67,
#  90,
#  88,
#  61,
#  7,
#  101,
#  84,
#  0,
#  4,
#  38,
#  29,
#  64,
#  48,
#  103,
#  22,
#  99,
#  11,
#  68,
#  55,
#  53,
#  74,
#  73,
#  87,
#  22,
#  55,
#  98,
#  76,
#  23,
#  29,
#  6,
#  101,
#  41,
#  92,
#  106,
#  84,
#  13,
#  8,
#  44,
#  95,
#  46,
#  60,
#  61,
#  76,
#  83,
#  78,
#  105,
#  107,
#  22,
#  63,
#  36,
#  22,
#  59,
#  14,
#  109,
#  40,
#  104,
#  108,
#  41,
#  72,
#  53,
#  41,
#  95,
#  39,
#  17,
#  89,
#  102,
#  57,
#  10,
#  112,
#  96,
#  1,
#  57,
#  23,
#  87,
#  12,
#  101,
#  53,
#  78,
#  106,
#  77,
#  63,
#  85,
#  53,
#  5,
#  74,
#  84,
#  74,
#  75,
#  43,
#  75,
#  101,
#  101,
#  51,
#  6,
#  69,
#  85,
#  55,
#  52,
#  16,
#  48,
#  2,
#  53,
#  1,
#  8,
#  75,
#  17,
#  35,
#  112,
#  8,
#  67,
#  86,
#  31,
#  97,
#  14,
#  57,
#  76,
#  35,
#  24,
#  87,
#  96,
#  6,
#  111,
#  23,
#  31,
#  54,
#  78,
#  53,
#  105,
#  42,
#  11,
#  11,
#  36,
#  98,
#  92,
#  78,
#  55,
#  20,
#  44,
#  1,
#  61,
#  72,
#  25,
#  107,
#  67,
#  97,
#  56,
#  61,
#  70,
#  77,
#  71,
#  69,
#  112,
#  42,
#  13,
#  57,
#  102,
#  2,
#  45,
#  95,
#  40,
#  1,
#  55,
#  103,
#  21,
#  58,
#  39,
#  46,
#  43,
#  65,
#  10,
#  112,
#  50,
#  85,
#  90,
#  29,
#  57,
#  89,
#  53,
#  99,
#  100,
#  12,
#  100,
#  12,
#  10,
#  73,
#  112,
#  90,
#  66,
#  22,
#  38,
#  67,
#  86,
#  100,
#  44,
#  27,
#  25,
#  32,
#  45,
#  84,
#  73,
#  10,
#  73,
#  24,
#  58,
#  90,
#  103,
#  27,
#  108,
#  28,
#  0,
#  47,
#  16,
#  55,
#  85,
#  9,
#  23,
#  91,
#  109,
#  65,
#  109,
#  57,
#  42,
#  43,
#  102,
#  108,
#  88,
#  89,
#  50,
#  71,
#  54,
#  2,
#  22,
#  44,
#  13,
#  87,
#  71,
#  104,
#  25,
#  43,
#  48,
#  85,
#  75,
#  40,
#  110,
#  86,
#  84,
#  28,
#  75,
#  60,
#  32,
#  113,
#  89,
#  65,
#  63,
#  6,
#  0,
#  10,
#  36,
#  89,
#  3,
#  16,
#  105,
#  113,
#  65,
#  109,
#  85,
#  13,
#  38,
#  70,
#  7,
#  74,
#  0,
#  23,
#  30,
#  85,
#  78,
#  30,
#  100,
#  24,
#  81,
#  103,
#  25,
#  44,
#  101,
#  16,
#  97,
#  4,
#  110,
#  88,
#  80,
#  89,
#  64,
#  40,
#  93,
#  51,
#  69,
#  2,
#  64,
#  56,
#  54,
#  37,
#  23,
#  21,
#  110,
#  9,
#  111,
#  90,
#  103,
#  75,
#  53,
#  42,
#  74,
#  33,
#  73,
#  14,
#  72,
#  83,
#  32,
#  1,
#  25,
#  0,
#  24,
#  87,
#  28,
#  77,
#  28,
#  93,
#  63,
#  33,
#  113,
#  89,
#  87,
#  15,
#  39,
#  16,
#  15,
#  15,
#  31,
#  4,
#  106,
#  18,
#  20,
#  108,
#  81,
#  18,
#  24,
#  70,
#  88,
#  12,
#  84,
#  66,
#  67,
#  34,
#  39,
#  7,
#  3,
#  6,
#  37,
#  97,
#  9,
#  79,
#  11,
#  32,
#  35,
#  74,
#  39,
#  100,
#  90,
#  105,
#  55,
#  37,
#  49,
#  59,
#  92,
#  65,
#  58,
#  15,
#  94,
#  109,
#  72,
#  69,
#  5,
#  107,
#  70,
#  52,
#  44,
#  96,
#  77,
#  111,
#  80,
#  64,
#  13,
#  85,
#  5,
#  62,
#  29,
#  113,
#  34,
#  9,
#  73,
#  91,
#  66,
#  0,
#  59,
#  13,
#  36,
#  95,
#  87,
#  92,
#  80,
#  101,
#  29,
#  46,
#  86,
#  76,
#  61,
#  78,
#  5,
#  56,
#  95,
#  74,
#  9,
#  97,
#  74,
#  18,
#  85,
#  60,
#  90,
#  80,
#  3,
#  86,
#  111,
#  2,
#  65,
#  104,
#  42,
#  50,
#  27,
#  79,
#  84,
#  111,
#  94,
#  51,
#  68,
#  26,
#  50,
#  98,
#  40,
#  79,
#  12,
#  52,
#  52,
#  100,
#  20,
#  ...]

# %%
df['track_genre_num'] = train_labels_num

# %%
df[10:20]
# Out:
#                   track_id            artists  \
# 10  2sxzZLirKtZchuUlECg9C1          Mara Lima
# 11  4dDminjzc0pePZIetS8mlZ   Rafael Lechowski
# 12  0oerlffJSzhRVvtDfLcp3N           Bon Jovi
# 13  20DigsfRILHYKeMqbuDqtx  Sweet Little Band
# 14  3AIPpo3z8KTN4hHhY7qRw8        Los Hitters
# 15  6nvbYcbL79UQ5VFKE0aeeq          Kari Jobe
# 16  6bcIyAwnUIF34YelBWqMrS            Therion
# 17  5kEOGfiGkDwGnNoGlepPJI             INSITE
# 18  59kkETYRczNrB6VOasIpxC       Oscar D'León
# 19  5LqdIFraDk9bpzD0pRoBdl     Toninho Geraes
#
#                                     album_name  \
# 10                         Recordações, Vol. 2
# 11                  El Canto de Amor a la Vida
# 12                           Slippery When Wet
# 13                         Coldplay Para bebes
# 14                              Grandes Exitos
# 15                         Sad Love Songs 2022
# 16                                  Les Épaves
# 17                   Una Vida No Es Suficiente
# 18                             Salsa x siempre
# 19  Tudo Que Sou, Vol. 1: Fragmentos (Ao Vivo)
#
#                                            track_name  popularity  \
# 10                                 Divino Companheiro          39
# 11              Desear Lo Que Ya Es Nuestro (Respira)          29
# 12                               Wanted Dead Or Alive          75
# 13                                        In My Place          30
# 14                               Un Hombre Respetable          39
# 15  In The Name Of Love - Recorded At Spotify Stud...           2
# 16                  L'amour est bleu - Mellow Version          22
# 17                                         Destrózame          36
# 18                                      Que Se Sienta           0
# 19                          Se a Fila Andar - Ao Vivo          43
#
#     duration_ms  explicit  danceability  energy  key  ...  mode  speechiness  \
# 10       203624         0         0.420   0.560    0  ...     1       0.0379
# 11       245680         0         0.550   0.674    1  ...     1       0.0617
# 12       308666         0         0.252   0.802    7  ...     1       0.0391
# 13       192493         0         0.503   0.263    9  ...     1       0.0298
# 14       150413         0         0.563   0.646    9  ...     0       0.1170
# 15       205738         0         0.675   0.375    6  ...     1       0.0452
# 16       207306         0         0.556   0.675    7  ...     1       0.0238
# 17       205080         0         0.482   0.929    0  ...     1       0.0468
# 18       285663         0         0.597   0.829   10  ...     1       0.0369
# 19       270982         0         0.536   0.809   11  ...     0       0.0707
#
#     acousticness  instrumentalness  liveness  valence    tempo  \
# 10       0.36900          0.000000    0.2650    0.430  199.451
# 11       0.47800          0.000108    0.1060    0.530   81.137
# 12       0.13000          0.014600    0.3090    0.253  150.056
# 13       0.94300          0.943000    0.0845    0.152  143.948
# 14       0.15600          0.000000    0.3100    0.592  175.107
# 15       0.54200          0.000003    0.0951    0.187  134.023
# 16       0.02480          0.001600    0.1440    0.357  105.024
# 17       0.00105          0.000000    0.0729    0.317   97.543
# 18       0.37800          0.000023    0.0649    0.921  171.491
# 19       0.62800          0.000000    0.9640    0.460   95.040
#
#     time_signature  track_genre track_genre_num
# 10               3       gospel              78
# 11               4      spanish              44
# 12               4        metal              13
# 13               4     children               1
# 14               4  rock-n-roll              87
# 15               4  alternative              53
# 16               4  black-metal              47
# 17               4    punk-rock              43
# 18               4        salsa              50
# 19               4        samba              81
#
# [10 rows x 21 columns]

# %%
# dividing dataset to data to train and data to test
train_dataset = df.sample(frac=0.8,random_state=0)
test_dataset = df.drop(train_dataset.index)

# %%
train_dataset.shape
# Out:
# (72959, 21)

# %%
test_dataset.shape
# Out:
# (18240, 21)

# %%
#know the column labels from dataset
train_dataset.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre', 'track_genre_num'],
#       dtype='object')

# %%
#sns.pairplot(train_dataset[['popularity',
#       'duration_ms', 'explicit', 'danceability', 'energy', 'loudness', 'key',
#       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#       'valence', 'tempo', 'time_signature', 'track_genre']], diag_kind="kde")

# %%
train_dataset = train_dataset.drop(['track_id','artists','album_name','track_name','key','time_signature','track_genre'],axis=1)

# %%
train_labels = train_dataset.pop('track_genre_num')

# %%
train_labels
# Out:
# 5413      42
# 64083    102
# 62381     73
# 24917     89
# 73671     79
#         ...
# 9457      55
# 58285    107
# 89873    112
# 62841     69
# 75130     17
# Name: track_genre_num, Length: 72959, dtype: int64

# %%
train_stats = train_dataset.describe()
train_stats = train_stats.transpose()
train_stats
# Out:
#                     count           mean            std       min  \
# popularity        72959.0      33.331529      22.294772     0.000
# duration_ms       72959.0  227690.246810  106562.673902  8586.000
# explicit          72959.0       0.086501       0.281104     0.000
# danceability      72959.0       0.567351       0.173699     0.000
# energy            72959.0       0.641243       0.251494     0.000
# loudness          72959.0      -8.266214       5.055703   -49.531
# mode              72959.0       0.637564       0.480707     0.000
# speechiness       72959.0       0.084279       0.104907     0.000
# acousticness      72959.0       0.314746       0.332257     0.000
# instrumentalness  72959.0       0.155217       0.309202     0.000
# liveness          72959.0       0.213076       0.189739     0.000
# valence           72959.0       0.474543       0.259265     0.000
# tempo             72959.0     122.131050      30.012755     0.000
#
#                           25%           50%          75%          max
# popularity            17.0000      35.00000      50.0000      100.000
# duration_ms       174062.0000  212845.00000  260907.5000  4789026.000
# explicit               0.0000       0.00000       0.0000        1.000
# danceability           0.4560       0.58100       0.6960        0.985
# energy                 0.4730       0.68400       0.8530        1.000
# loudness             -10.0200      -7.00000      -4.9995        3.156
# mode                   0.0000       1.00000       1.0000        1.000
# speechiness            0.0359       0.04890       0.0842        0.965
# acousticness           0.0170       0.16900       0.5970        0.996
# instrumentalness       0.0000       0.00004       0.0461        1.000
# liveness               0.0980       0.13200       0.2730        1.000
# valence                0.2600       0.46400       0.6830        0.995
# tempo                 99.0850     122.01500     140.0800      243.372

# %%
train_dataset.transpose()
# Out:
#                           5413          64083        62381        24917  \
# popularity             0.000000     18.000000      54.0000      44.0000
# duration_ms       164818.000000  67725.000000  200021.0000  193012.0000
# explicit               0.000000      0.000000       0.0000       0.0000
# danceability           0.754000      0.435000       0.7760       0.8460
# energy                 0.763000      0.712000       0.8140       0.7470
# loudness              -4.627000     -8.452000      -5.8600      -5.9980
# mode                   0.000000      1.000000       0.0000       0.0000
# speechiness            0.043500      0.153000       0.0737       0.0694
# acousticness           0.030100      0.000163       0.0336       0.0694
# instrumentalness       0.000022      0.916000       0.0000       0.0000
# liveness               0.090100      0.184000       0.1090       0.1440
# valence                0.464000      0.289000       0.8310       0.7900
# tempo                117.953000    132.446000     118.0320     128.0070
#
#                           73671        85455        83795          68260  \
# popularity            23.000000      10.0000      10.0000      78.000000
# duration_ms       268426.000000  183169.0000  156720.0000  241970.000000
# explicit               0.000000       0.0000       0.0000       0.000000
# danceability           0.546000       0.4230       0.4050       0.727000
# energy                 0.969000       0.2060       0.4690       0.681000
# loudness              -5.050000     -23.2090     -12.3200      -7.114000
# mode                   0.000000       0.0000       1.0000       0.000000
# speechiness            0.051200       0.0345       0.0437       0.026500
# acousticness           0.001960       0.9360       0.4520       0.002140
# instrumentalness       0.000051       0.9470       0.0000       0.000307
# liveness               0.142000       0.1000       0.3830       0.086100
# valence                0.460000       0.0369       0.9210       0.448000
# tempo                114.984000      95.8050     205.4020     123.028000
#
#                           52875          55544  ...       75202        9057   \
# popularity            43.000000       0.000000  ...       0.000      56.0000
# duration_ms       380800.000000  129332.000000  ...  229826.000  177525.0000
# explicit               0.000000       0.000000  ...       0.000       1.0000
# danceability           0.224000       0.798000  ...       0.714       0.7030
# energy                 0.499000       0.625000  ...       0.671       0.4980
# loudness              -7.400000      -6.830000  ...      -5.119      -6.6880
# mode                   0.000000       1.000000  ...       1.000       0.0000
# speechiness            0.037900       0.130000  ...       0.362       0.0805
# acousticness           0.037900       0.383000  ...       0.292       0.0639
# instrumentalness       0.000007       0.000033  ...       0.000       0.0284
# liveness               0.078000       0.125000  ...       0.325       0.1130
# valence                0.125000       0.774000  ...       0.641       0.3640
# tempo                149.733000      92.994000  ...     169.727     132.5030
#
#                           86998        39291       60543        9457   \
# popularity             1.000000      53.0000      66.000       1.0000
# duration_ms       266706.000000  232178.0000  169813.000  630595.0000
# explicit               0.000000       0.0000       0.000       0.0000
# danceability           0.485000       0.8490       0.623       0.1590
# energy                 0.924000       0.3780       0.796       0.1810
# loudness              -4.046000     -11.9720      -2.981     -18.4120
# mode                   1.000000       0.0000       0.000       1.0000
# speechiness            0.057900       0.0455       0.199       0.0566
# acousticness           0.037300       0.3240       0.659       0.9790
# instrumentalness       0.000002       0.5830       0.000       0.9120
# liveness               0.248000       0.2930       0.115       0.0720
# valence                0.661000       0.2290       0.607       0.0334
# tempo                143.244000     116.9980     197.524      73.9040
#
#                           58285          89873        62841       75130
# popularity            21.000000      76.000000       0.0000       0.000
# duration_ms       278520.000000  194165.000000  159735.0000  227280.000
# explicit               0.000000       1.000000       0.0000       0.000
# danceability           0.599000       0.609000       0.6820       0.874
# energy                 0.583000       0.449000       0.9190       0.690
# loudness              -6.960000     -13.291000      -3.1800      -6.373
# mode                   1.000000       0.000000       0.0000       1.000
# speechiness            0.027300       0.249000       0.0874       0.114
# acousticness           0.624000       0.326000       0.2560       0.121
# instrumentalness       0.000078       0.000115       0.0000       0.000
# liveness               0.370000       0.147000       0.4430       0.249
# valence                0.365000       0.309000       0.5350       0.735
# tempo                 98.086000     143.854000      95.9830      95.025
#
# [13 rows x 72959 columns]

# %% [markdown]
# # Normalizando los datos

# %%
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)

normed_train_data.describe().transpose()
# Out:
#                     count          mean  std       min       25%       50%  \
# popularity        72959.0  1.967690e-16  1.0 -1.495038 -0.732527  0.074837
# duration_ms       72959.0  4.342160e-17  1.0 -2.056107 -0.503255 -0.139310
# explicit          72959.0 -5.074988e-16  1.0 -0.307718 -0.307718 -0.307718
# danceability      72959.0  5.179309e-14  1.0 -3.266287 -0.641055  0.078581
# energy            72959.0 -8.411438e-15  1.0 -2.549740 -0.668977  0.170011
# loudness          72959.0  2.202361e-14  1.0 -8.162027 -0.346893  0.250453
# mode              72959.0 -3.361163e-15  1.0 -1.326303 -1.326303  0.753965
# speechiness       72959.0  2.089112e-14  1.0 -0.803361 -0.461155 -0.337236
# acousticness      72959.0  8.131865e-15  1.0 -0.947298 -0.896133 -0.438656
# instrumentalness  72959.0  9.368210e-15  1.0 -0.501991 -0.501991 -0.501861
# liveness          72959.0 -9.422616e-15  1.0 -1.122998 -0.606498 -0.427305
# valence           72959.0 -2.344053e-14  1.0 -1.830338 -0.827504 -0.040665
# tempo             72959.0 -8.041646e-15  1.0 -4.069305 -0.767875 -0.003867
#
#                        75%        max
# popularity        0.747640   2.990319
# duration_ms       0.311716  42.804254
# explicit         -0.307718   3.249687
# danceability      0.740646   2.404445
# energy            0.841996   1.426504
# loudness          0.646144   2.259273
# mode              0.753965   0.753965
# speechiness      -0.000749   8.395221
# acousticness      0.849504   2.050381
# instrumentalness -0.352897   2.732141
# liveness          0.315821   4.147401
# valence           0.804030   2.007430
# tempo             0.598044   4.039647

# %%
normed_train_data.transpose()
# Out:
#                      5413      64083     62381     24917     73671     85455  \
# popularity       -1.495038 -0.687674  0.927055  0.478519 -0.463406 -1.046502
# duration_ms      -0.590003 -1.501138 -0.259652 -0.325426  0.382270 -0.417794
# explicit         -0.307718 -0.307718 -0.307718 -0.307718 -0.307718 -0.307718
# danceability      1.074557 -0.761954  1.201213  1.604209 -0.122917 -0.831039
# energy            0.484134  0.281346  0.686922  0.420514  1.303240 -1.730633
# loudness          0.719824 -0.036748  0.475941  0.448645  0.636156 -2.955630
# mode             -1.326303  0.753965 -1.326303 -1.326303 -1.326303 -1.326303
# speechiness      -0.388710  0.655067 -0.100837 -0.141826 -0.315312 -0.474500
# acousticness     -0.856706 -0.946808 -0.846172 -0.738424 -0.941399  1.869798
# instrumentalness -0.501919  2.460474 -0.501991 -0.501991 -0.501825  2.560732
# liveness         -0.648135 -0.153244 -0.548524 -0.364060 -0.374601 -0.595958
# valence          -0.040665 -0.715650  1.374873  1.216734 -0.056093 -1.688013
# tempo            -0.139209  0.343686 -0.136577  0.195782 -0.238134 -0.877162
#
#                      83795     68260     52875     55544  ...     75202  \
# popularity       -1.046502  2.003540  0.433665 -1.495038  ... -1.495038
# duration_ms      -0.665995  0.134003  1.436805 -0.923008  ...  0.020042
# explicit         -0.307718 -0.307718 -0.307718 -0.307718  ... -0.307718
# danceability     -0.934666  0.919116 -1.976699  1.327869  ...  0.844274
# energy           -0.684882  0.158082 -0.565594 -0.064588  ...  0.118320
# loudness         -0.801824  0.227904  0.171334  0.284078  ...  0.622508
# mode              0.753965 -1.326303 -1.326303  0.753965  ...  0.753965
# speechiness      -0.386804 -0.550758 -0.442090  0.435826  ...  2.647298
# acousticness      0.413095 -0.940857 -0.833230  0.205424  ... -0.068460
# instrumentalness -0.501991 -0.500998 -0.501967 -0.501883  ... -0.501991
# liveness          0.895565 -0.669216 -0.711906 -0.464198  ...  0.589882
# valence           1.722008 -0.102378 -1.348206  1.155021  ...  0.642033
# tempo             2.774519  0.029886  0.919674 -0.970822  ...  1.585857
#
#                      9057      86998     39291     60543     9457      58285  \
# popularity        1.016762 -1.450184  0.882201  1.465297 -1.450184 -0.553113
# duration_ms      -0.470758  0.366130  0.042114 -0.543129  3.780918  0.476994
# explicit          3.249687 -0.307718 -0.307718 -0.307718 -0.307718 -0.307718
# danceability      0.780946 -0.474099  1.621481  0.320379 -2.350910  0.182209
# energy           -0.569570  1.124309 -1.046720  0.615350 -1.830040 -0.231590
# loudness          0.312165  0.834743 -0.732991  1.045396 -2.006800  0.258364
# mode             -1.326303  0.753965 -1.326303 -1.326303  0.753965  0.753965
# speechiness      -0.036018 -0.251446 -0.369646  1.093548 -0.263838 -0.543132
# acousticness     -0.754977 -0.835036  0.027851  1.036106  1.999216  0.930766
# instrumentalness -0.410141 -0.501985  1.383508 -0.501991  2.447538 -0.501737
# liveness         -0.527442  0.184061  0.421229 -0.516902 -0.743529  0.827050
# valence          -0.426371  0.719174 -0.947073  0.510893 -1.701512 -0.422513
# tempo             0.345585  0.703466 -0.171029  2.512030 -1.606885 -0.801161
#
#                      89873     62841     75130
# popularity        1.913833 -1.495038 -1.495038
# duration_ms      -0.314606 -0.637702 -0.003850
# explicit          3.249687 -0.307718 -0.307718
# danceability      0.239780  0.660047  1.765408
# energy           -0.764406  1.104428  0.193868
# loudness         -0.993885  1.006035  0.374471
# mode             -1.326303 -1.326303  0.753965
# speechiness       1.570159  0.029754  0.283311
# acousticness      0.033870 -0.176810 -0.583122
# instrumentalness -0.501619 -0.501991 -0.501991
# liveness         -0.348249  1.211789  0.189332
# valence          -0.638508  0.233186  1.004596
# tempo             0.723791 -0.871231 -0.903151
#
# [13 rows x 72959 columns]

# %% [markdown]
# # Construyendo el modelo

# %%
len(normed_train_data.keys())
# Out:
# 13

# %%
normed_train_data.keys()
# Out:
# Index(['popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
normed_train_data.shape
# Out:
# (72959, 13)

# %%
len(label_dict)
# Out:
# 114

# %%
model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=[len(normed_train_data.keys())]),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(len(label_dict), activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Train Model

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 256)               3584
#
#  dense_19 (Dense)            (None, 512)               131584
#
#  dense_20 (Dense)            (None, 114)               58482
#
# =================================================================
# Total params: 193,650
# Trainable params: 193,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(type(normed_train_data))
print(type(train_labels))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
hist = model.fit(normed_train_data, train_labels, validation_split = 0.2, epochs=100)
# Out:
# Epoch 1/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 3.2628 - accuracy: 0.2019 - val_loss: 3.0109 - val_accuracy: 0.2392
# Epoch 2/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.8724 - accuracy: 0.2618 - val_loss: 2.8247 - val_accuracy: 0.2728
# Epoch 3/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.7140 - accuracy: 0.2895 - val_loss: 2.7511 - val_accuracy: 0.2854
# Epoch 4/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.6008 - accuracy: 0.3095 - val_loss: 2.6751 - val_accuracy: 0.2946
# Epoch 5/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.5145 - accuracy: 0.3231 - val_loss: 2.6393 - val_accuracy: 0.3033
# Epoch 6/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.4457 - accuracy: 0.3347 - val_loss: 2.6143 - val_accuracy: 0.3065
# Epoch 7/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.3863 - accuracy: 0.3457 - val_loss: 2.6206 - val_accuracy: 0.3069
# Epoch 8/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.3303 - accuracy: 0.3544 - val_loss: 2.6046 - val_accuracy: 0.3127
# Epoch 9/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.2814 - accuracy: 0.3632 - val_loss: 2.6104 - val_accuracy: 0.3131
# Epoch 10/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.2344 - accuracy: 0.3733 - val_loss: 2.6121 - val_accuracy: 0.3144
# Epoch 11/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.1871 - accuracy: 0.3818 - val_loss: 2.6210 - val_accuracy: 0.3137
# Epoch 12/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.1467 - accuracy: 0.3900 - val_loss: 2.6366 - val_accuracy: 0.3122
# Epoch 13/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.1029 - accuracy: 0.4011 - val_loss: 2.6435 - val_accuracy: 0.3130
# Epoch 14/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.0647 - accuracy: 0.4046 - val_loss: 2.6627 - val_accuracy: 0.3093
# Epoch 15/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 2.0266 - accuracy: 0.4134 - val_loss: 2.6738 - val_accuracy: 0.3135
# Epoch 16/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.9905 - accuracy: 0.4204 - val_loss: 2.7044 - val_accuracy: 0.3147
# Epoch 17/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.9554 - accuracy: 0.4259 - val_loss: 2.7176 - val_accuracy: 0.3114
# Epoch 18/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.9206 - accuracy: 0.4356 - val_loss: 2.7558 - val_accuracy: 0.3091
# Epoch 19/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.8885 - accuracy: 0.4409 - val_loss: 2.7831 - val_accuracy: 0.3111
# Epoch 20/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.8582 - accuracy: 0.4486 - val_loss: 2.8156 - val_accuracy: 0.3072
# Epoch 21/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.8263 - accuracy: 0.4547 - val_loss: 2.8477 - val_accuracy: 0.3038
# Epoch 22/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.7967 - accuracy: 0.4596 - val_loss: 2.8811 - val_accuracy: 0.2995
# Epoch 23/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.7673 - accuracy: 0.4674 - val_loss: 2.8937 - val_accuracy: 0.3012
# Epoch 24/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.7407 - accuracy: 0.4733 - val_loss: 2.9166 - val_accuracy: 0.3022
# Epoch 25/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.7139 - accuracy: 0.4769 - val_loss: 2.9913 - val_accuracy: 0.2998
# Epoch 26/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.6898 - accuracy: 0.4852 - val_loss: 3.0204 - val_accuracy: 0.2992
# Epoch 27/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.6638 - accuracy: 0.4912 - val_loss: 3.0284 - val_accuracy: 0.2952
# Epoch 28/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.6365 - accuracy: 0.4976 - val_loss: 3.0813 - val_accuracy: 0.2961
# Epoch 29/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.6134 - accuracy: 0.5017 - val_loss: 3.1160 - val_accuracy: 0.2936
# Epoch 30/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.5938 - accuracy: 0.5076 - val_loss: 3.1259 - val_accuracy: 0.2952
# Epoch 31/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.5718 - accuracy: 0.5127 - val_loss: 3.1582 - val_accuracy: 0.2924
# Epoch 32/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.5503 - accuracy: 0.5177 - val_loss: 3.2128 - val_accuracy: 0.2921
# Epoch 33/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.5294 - accuracy: 0.5239 - val_loss: 3.2475 - val_accuracy: 0.2956
# Epoch 34/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.5100 - accuracy: 0.5271 - val_loss: 3.2950 - val_accuracy: 0.2927
# Epoch 35/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.4896 - accuracy: 0.5335 - val_loss: 3.3395 - val_accuracy: 0.2889
# Epoch 36/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.4680 - accuracy: 0.5369 - val_loss: 3.3710 - val_accuracy: 0.2900
# Epoch 37/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.4509 - accuracy: 0.5400 - val_loss: 3.4289 - val_accuracy: 0.2878
# Epoch 38/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.4306 - accuracy: 0.5476 - val_loss: 3.4393 - val_accuracy: 0.2878
# Epoch 39/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.4163 - accuracy: 0.5490 - val_loss: 3.4962 - val_accuracy: 0.2859
# Epoch 40/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.3994 - accuracy: 0.5534 - val_loss: 3.5148 - val_accuracy: 0.2873
# Epoch 41/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.3820 - accuracy: 0.5567 - val_loss: 3.5608 - val_accuracy: 0.2821
# Epoch 42/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 1.3665 - accuracy: 0.5624 - val_loss: 3.6212 - val_accuracy: 0.2832
# Epoch 43/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.3521 - accuracy: 0.5658 - val_loss: 3.6416 - val_accuracy: 0.2808
# Epoch 44/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.3352 - accuracy: 0.5693 - val_loss: 3.6772 - val_accuracy: 0.2795
# Epoch 45/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.3180 - accuracy: 0.5735 - val_loss: 3.7747 - val_accuracy: 0.2772
# Epoch 46/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.3049 - accuracy: 0.5792 - val_loss: 3.7859 - val_accuracy: 0.2804
# Epoch 47/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.2938 - accuracy: 0.5813 - val_loss: 3.8254 - val_accuracy: 0.2814
# Epoch 48/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.2807 - accuracy: 0.5831 - val_loss: 3.8874 - val_accuracy: 0.2756
# Epoch 49/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.2627 - accuracy: 0.5870 - val_loss: 3.9454 - val_accuracy: 0.2791
# Epoch 50/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.2531 - accuracy: 0.5911 - val_loss: 3.9291 - val_accuracy: 0.2774
# Epoch 51/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.2405 - accuracy: 0.5955 - val_loss: 3.9731 - val_accuracy: 0.2760
# Epoch 52/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.2298 - accuracy: 0.5966 - val_loss: 3.9942 - val_accuracy: 0.2747
# Epoch 53/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.2169 - accuracy: 0.5994 - val_loss: 4.0967 - val_accuracy: 0.2775
# Epoch 54/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.2038 - accuracy: 0.6026 - val_loss: 4.1251 - val_accuracy: 0.2725
# Epoch 55/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.1957 - accuracy: 0.6068 - val_loss: 4.1669 - val_accuracy: 0.2797
# Epoch 56/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.1817 - accuracy: 0.6110 - val_loss: 4.2065 - val_accuracy: 0.2770
# Epoch 57/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.1704 - accuracy: 0.6131 - val_loss: 4.2336 - val_accuracy: 0.2793
# Epoch 58/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.1607 - accuracy: 0.6179 - val_loss: 4.2965 - val_accuracy: 0.2715
# Epoch 59/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.1486 - accuracy: 0.6178 - val_loss: 4.3221 - val_accuracy: 0.2730
# Epoch 60/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 1.1415 - accuracy: 0.6207 - val_loss: 4.3506 - val_accuracy: 0.2736
# Epoch 61/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.1305 - accuracy: 0.6230 - val_loss: 4.4017 - val_accuracy: 0.2695
# Epoch 62/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.1236 - accuracy: 0.6241 - val_loss: 4.4222 - val_accuracy: 0.2754
# Epoch 63/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.1132 - accuracy: 0.6275 - val_loss: 4.4910 - val_accuracy: 0.2762
# Epoch 64/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.1026 - accuracy: 0.6303 - val_loss: 4.5067 - val_accuracy: 0.2739
# Epoch 65/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.0893 - accuracy: 0.6333 - val_loss: 4.5820 - val_accuracy: 0.2700
# Epoch 66/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 1.0824 - accuracy: 0.6364 - val_loss: 4.6318 - val_accuracy: 0.2679
# Epoch 67/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.0777 - accuracy: 0.6383 - val_loss: 4.6366 - val_accuracy: 0.2712
# Epoch 68/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 1.0638 - accuracy: 0.6413 - val_loss: 4.6948 - val_accuracy: 0.2685
# Epoch 69/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 1.0590 - accuracy: 0.6419 - val_loss: 4.7200 - val_accuracy: 0.2676
# Epoch 70/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 1.0504 - accuracy: 0.6451 - val_loss: 4.7777 - val_accuracy: 0.2723
# Epoch 71/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 1.0406 - accuracy: 0.6490 - val_loss: 4.8337 - val_accuracy: 0.2679
# Epoch 72/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 1.0341 - accuracy: 0.6499 - val_loss: 4.8432 - val_accuracy: 0.2723
# Epoch 73/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.0305 - accuracy: 0.6502 - val_loss: 4.8958 - val_accuracy: 0.2640
# Epoch 74/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 1.0206 - accuracy: 0.6545 - val_loss: 4.9363 - val_accuracy: 0.2712
# Epoch 75/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.0168 - accuracy: 0.6523 - val_loss: 4.9924 - val_accuracy: 0.2657
# Epoch 76/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 1.0086 - accuracy: 0.6570 - val_loss: 5.0079 - val_accuracy: 0.2681
# Epoch 77/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.9975 - accuracy: 0.6609 - val_loss: 5.0808 - val_accuracy: 0.2684
# Epoch 78/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.9896 - accuracy: 0.6627 - val_loss: 5.1110 - val_accuracy: 0.2672
# Epoch 79/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.9813 - accuracy: 0.6655 - val_loss: 5.1514 - val_accuracy: 0.2670
# Epoch 80/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.9756 - accuracy: 0.6671 - val_loss: 5.2387 - val_accuracy: 0.2674
# Epoch 81/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.9769 - accuracy: 0.6671 - val_loss: 5.2574 - val_accuracy: 0.2643
# Epoch 82/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.9698 - accuracy: 0.6651 - val_loss: 5.2492 - val_accuracy: 0.2632
# Epoch 83/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.9592 - accuracy: 0.6700 - val_loss: 5.2832 - val_accuracy: 0.2668
# Epoch 84/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.9546 - accuracy: 0.6713 - val_loss: 5.2859 - val_accuracy: 0.2654
# Epoch 85/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.9516 - accuracy: 0.6746 - val_loss: 5.3774 - val_accuracy: 0.2632
# Epoch 86/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.9424 - accuracy: 0.6753 - val_loss: 5.4372 - val_accuracy: 0.2649
# Epoch 87/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.9373 - accuracy: 0.6784 - val_loss: 5.4660 - val_accuracy: 0.2671
# Epoch 88/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.9325 - accuracy: 0.6802 - val_loss: 5.4804 - val_accuracy: 0.2658
# Epoch 89/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.9291 - accuracy: 0.6779 - val_loss: 5.4957 - val_accuracy: 0.2603
# Epoch 90/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.9229 - accuracy: 0.6817 - val_loss: 5.5770 - val_accuracy: 0.2624
# Epoch 91/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.9142 - accuracy: 0.6845 - val_loss: 5.5848 - val_accuracy: 0.2633
# Epoch 92/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.9149 - accuracy: 0.6843 - val_loss: 5.6043 - val_accuracy: 0.2604
# Epoch 93/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.9072 - accuracy: 0.6869 - val_loss: 5.6828 - val_accuracy: 0.2653
# Epoch 94/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.8988 - accuracy: 0.6877 - val_loss: 5.7016 - val_accuracy: 0.2615
# Epoch 95/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.8977 - accuracy: 0.6897 - val_loss: 5.7306 - val_accuracy: 0.2579
# Epoch 96/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.8944 - accuracy: 0.6904 - val_loss: 5.7652 - val_accuracy: 0.2619
# Epoch 97/100
# 1824/1824 [==============================] - 3s 1ms/step - loss: 0.8868 - accuracy: 0.6936 - val_loss: 5.8331 - val_accuracy: 0.2631
# Epoch 98/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.8844 - accuracy: 0.6922 - val_loss: 5.8586 - val_accuracy: 0.2613
# Epoch 99/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.8759 - accuracy: 0.6957 - val_loss: 5.8721 - val_accuracy: 0.2617
# Epoch 100/100
# 1824/1824 [==============================] - 3s 2ms/step - loss: 0.8779 - accuracy: 0.6955 - val_loss: 5.8993 - val_accuracy: 0.2606

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('loss')
    plt.plot(hist['epoch'], hist['loss'],
           label='Train Error')
    plt.plot(hist['epoch'], hist['val_loss'],
           label = 'Val Error')
    plt.ylim([0,5])
    plt.legend()

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('loss')
    plt.plot(hist['epoch'], hist['loss'],
           label='Train Error')
    plt.plot(hist['epoch'], hist['val_loss'],
           label = 'Val Error')
    plt.ylim([0,5])
    plt.legend()
    plt.show()

plot_history(hist)
